# %% [markdown]
# # Instalando Biblioteca
# ### pip install yfinence
# ### pip install matplotlib

# %%
'pip install yfinance'
'pip install matplotlib'
'pip install pandas'
# Out:
# 'pip install pandas'

# %% [markdown]
# ## Buscando os dados de uma ação

# %%
import yfinance as yf
import pandas as pd

def obter_dados_acao(ticker, dt_inicial, dt_final):
    try:
        dados = yf.Ticker(ticker)
        tabela = dados.history(start=dt_inicial, end=dt_final)
        return tabela
    except Exception as e:
        print(f"Erro ao buscar dados da ação {ticker}: {e}")
        return pd.DataFrame()

# Solicita os dados ao usuário
ticker = input("Digite o código da Ação: ")
dt_inicial = input("Digite a data inicial (aaaa-mm-dd): ")
dt_final = input("Digite a data final (aaaa-mm-dd): ")

# Chama a função e exibe os resultados
resultado = obter_dados_acao(ticker, dt_inicial, dt_final)

# %% [markdown]
# ### Selecionando apenas a coluna de Fechamento (close)

# %%
# Verifica se o DataFrame não está vazio antes de acessar a coluna 'close'
if not resultado.empty:
    fechamento = resultado['Close']
    print(fechamento)
else:
    print("Não foram encontrados dados para a ação.")
# Out:
# Date
# 2020-01-02 00:00:00-05:00     28.684000
# 2020-01-03 00:00:00-05:00     29.534000
# 2020-01-06 00:00:00-05:00     30.102667
# 2020-01-07 00:00:00-05:00     31.270666
# 2020-01-08 00:00:00-05:00     32.809334
#                                 ...
# 2020-12-23 00:00:00-05:00    215.326660
# 2020-12-24 00:00:00-05:00    220.589996
# 2020-12-28 00:00:00-05:00    221.229996
# 2020-12-29 00:00:00-05:00    221.996674
# 2020-12-30 00:00:00-05:00    231.593338
# Name: Close, Length: 252, dtype: float64

# %% [markdown]
# ### Gerando um gráfico de lina(usa a biblioteca matplotlib)

# %%
fechamento.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Gerando as estatísticas

# %%
maxima=round(fechamento.max(),2)
minima=round(fechamento.min(),2)
media=round(fechamento.mean(),2)

print(maxima)
print(minima)
print(media)
# Out:
# 231.67
# 24.08
# 96.12

# %% [markdown]
# ### Enviando e-mail de forma Automática

# %%
'pip install pyautogui'
# Out:
# 'pip install pyautogui'

# %% [markdown]
# ### Obtendo as coordenadas na tela

# %%
import time
import pyautogui

time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=1355, y=491)

# %%
import pyautogui
import pyperclip
import webbrowser
from time import sleep

destinatario = "epictechbr@gmail.com"
assunto = "Análise TSLA 2020"

Mensagem = """
Bom dia SR...

Segue abaixo as análises da Ação {} do período solicitado: {} a {}

Cotação Máxima: R${}
Cotação Mínima: R${}
Valor Médio: R${}
""".format(ticker, dt_inicial, dt_final, maxima, minima, media)

# Configurando uma pausa entre as ações do pyautogui
pyautogui.PAUSE = 3

# Abrir o navegador do gmail
webbrowser.open("http://gmail.com")
sleep(3)

# Cliando no botão "Escrever"
pyautogui.click(x=71, y=224)

# Preenchendo para o Destinatário
pyperclip.copy(destinatario)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

# Preenchendo o Assunto

pyperclip.copy(assunto)
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

# Preenchendo corpo do e-mail
pyperclip.copy(Mensagem)
pyautogui.hotkey("ctrl", "v")

# Clicando no Botão Enviar
pyautogui.click(x=488, y=999)

# Fechando a Aba da pagina
pyautogui.hotkey("ctrl", "f4")

print("E-mail enviado com Sucesso")
# Out:
# E-mail enviado com Sucesso
